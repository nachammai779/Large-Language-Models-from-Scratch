# %% [markdown]
# # BUILD A LARGE LANGUAGE MODEL FROM SCRATCH

# %% [markdown]
# ### STEP 1: LOADING THE DATASET

# %%
import os

file_path = "A History of Indian Philosophy Volume 1.txt"

# Check if the file exists in the current directory (i.e., Colab session)
if os.path.exists(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        raw_text = file.read()
    print(f"File '{file_path}' loaded with {len(text_data)} characters.")
else:
    print(f"File '{file_path}' not found. Please upload it to the Colab environment first.")
# Out:
# File 'A History of Indian Philosophy Volume 1.txt' loaded with 1342083 characters.

# %% [markdown]
# ### STEP 2: IMPLEMENTING THE TOKENIZER

# %%
# !pip3 install tiktoken > /dev/null 2>&1

# %%
import importlib
import tiktoken

print("tiktoken version:", importlib.metadata.version("tiktoken"))
# Out:
# tiktoken version: 0.12.0

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
total_characters = len(raw_text)
total_tokens = len(tokenizer.encode(raw_text))

print("Characters:", total_characters)
print("Tokens:", total_tokens)
# Out:
# Characters: 1342083
# Tokens: 357340

# %% [markdown]
# ### STEP 3: CREATING INPUT-TARGET PAIRS

# %%
with open("A History of Indian Philosophy Volume 1.txt", "r", encoding="utf-8") as f:
    raw_text = f.read()

enc_text = tokenizer.encode(raw_text)
print(len(enc_text))
# Out:
# 357340

# %%
from torch.utils.data import Dataset, DataLoader


class GPTDatasetV1(Dataset):
    def __init__(self, txt, tokenizer, max_length, stride):
        self.input_ids = []
        self.target_ids = []

        # Tokenize the entire text
        token_ids = tokenizer.encode(txt, allowed_special={"<|endoftext|>"})

        # Use a sliding window to chunk the book into overlapping sequences of max_length
        for i in range(0, len(token_ids) - max_length, stride):
            input_chunk = token_ids[i:i + max_length]
            target_chunk = token_ids[i + 1: i + max_length + 1]
            self.input_ids.append(torch.tensor(input_chunk))
            self.target_ids.append(torch.tensor(target_chunk))

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        return self.input_ids[idx], self.target_ids[idx]

# %%
def create_dataloader_v1(txt, batch_size=4, max_length=256,
                         stride=128, shuffle=True, drop_last=True,
                         num_workers=0):

    # Initialize the tokenizer
    tokenizer = tiktoken.get_encoding("gpt2")

    # Create dataset
    dataset = GPTDatasetV1(txt, tokenizer, max_length, stride)

    # Create dataloader
    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        drop_last=drop_last,
        num_workers=num_workers
    )

    return dataloader

# %%
import torch
print("PyTorch version:", torch.__version__)
dataloader = create_dataloader_v1(
    raw_text, batch_size=1, max_length=4, stride=1, shuffle=False
)

data_iter = iter(dataloader)
first_batch = next(data_iter)
print(first_batch)
# Out:
# PyTorch version: 2.10.0+cu128
# [tensor([[  464,  4935, 20336, 46566]]), tensor([[ 4935, 20336, 46566,   286]])]

# %% [markdown]
# ### STEP 4: IMPLEMENTING MULTI-HEAD ATTENTION

# %%
import torch.nn as nn

class MultiHeadAttention(nn.Module):
    def __init__(self, d_in, d_out, context_length, dropout, num_heads, qkv_bias=False):
        super().__init__()
        assert (d_out % num_heads == 0), \
            "d_out must be divisible by num_heads"

        self.d_out = d_out
        self.num_heads = num_heads
        self.head_dim = d_out // num_heads # Reduce the projection dim to match desired output dim

        self.W_query = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_key = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.W_value = nn.Linear(d_in, d_out, bias=qkv_bias)
        self.out_proj = nn.Linear(d_out, d_out)  # Linear layer to combine head outputs
        self.dropout = nn.Dropout(dropout)
        self.register_buffer(
            "mask",
            torch.triu(torch.ones(context_length, context_length),
                       diagonal=1)
        )

    def forward(self, x):
        b, num_tokens, d_in = x.shape

        keys = self.W_key(x) # Shape: (b, num_tokens, d_out)
        queries = self.W_query(x)
        values = self.W_value(x)

        # We implicitly split the matrix by adding a `num_heads` dimension
        # Unroll last dim: (b, num_tokens, d_out) -> (b, num_tokens, num_heads, head_dim)
        keys = keys.view(b, num_tokens, self.num_heads, self.head_dim)
        values = values.view(b, num_tokens, self.num_heads, self.head_dim)
        queries = queries.view(b, num_tokens, self.num_heads, self.head_dim)

        # Transpose: (b, num_tokens, num_heads, head_dim) -> (b, num_heads, num_tokens, head_dim)
        keys = keys.transpose(1, 2)
        queries = queries.transpose(1, 2)
        values = values.transpose(1, 2)

        # Compute scaled dot-product attention (aka self-attention) with a causal mask
        attn_scores = queries @ keys.transpose(2, 3)  # Dot product for each head

        # Original mask truncated to the number of tokens and converted to boolean
        mask_bool = self.mask.bool()[:num_tokens, :num_tokens]

        # Use the mask to fill attention scores
        attn_scores.masked_fill_(mask_bool, -torch.inf)

        attn_weights = torch.softmax(attn_scores / keys.shape[-1]**0.5, dim=-1)
        attn_weights = self.dropout(attn_weights)

        # Shape: (b, num_tokens, num_heads, head_dim)
        context_vec = (attn_weights @ values).transpose(1, 2)

        # Combine heads, where self.d_out = self.num_heads * self.head_dim
        context_vec = context_vec.contiguous().view(b, num_tokens, self.d_out)
        context_vec = self.out_proj(context_vec) # optional projection

        return context_vec

# %% [markdown]
# ### STEP 5: IMPLEMENTING A GPT MODEL FROM SCRATCH TO GENERATE TEXT

# %%
GPT_CONFIG_124M = {
    "vocab_size": 50257,    # Vocabulary size
    "context_length": 256, # Context length
    "emb_dim": 768,         # Embedding dimension
    "n_heads": 12,          # Number of attention heads
    "n_layers": 12,         # Number of layers
    "drop_rate": 0.1,       # Dropout rate
    "qkv_bias": False       # Query-Key-Value bias
}

# %% [markdown]
# ### STEP 6: THE BUILDING BLOCKS-LAYER NORMALIZATION, GELU AND FEED-FORWARD NEURAL NETWORK

# %%
class LayerNorm(nn.Module):
    def __init__(self, emb_dim):
        super().__init__()
        self.eps = 1e-5
        self.scale = nn.Parameter(torch.ones(emb_dim))
        self.shift = nn.Parameter(torch.zeros(emb_dim))

    def forward(self, x):
        mean = x.mean(dim=-1, keepdim=True)
        var = x.var(dim=-1, keepdim=True, unbiased=False)
        norm_x = (x - mean) / torch.sqrt(var + self.eps)
        return self.scale * norm_x + self.shift

class GELU(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return 0.5 * x * (1 + torch.tanh(
            torch.sqrt(torch.tensor(2.0 / torch.pi)) *
            (x + 0.044715 * torch.pow(x, 3))
        ))


class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.layers = nn.Sequential(
            nn.Linear(cfg["emb_dim"], 4 * cfg["emb_dim"]), ## Expansion
            GELU(), ## Activation
            nn.Linear(4 * cfg["emb_dim"], cfg["emb_dim"]), ## Contraction
        )

    def forward(self, x):
        return self.layers(x)

# %%
class TransformerBlock(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.att = MultiHeadAttention(
            d_in=cfg["emb_dim"],
            d_out=cfg["emb_dim"],
            context_length=cfg["context_length"],
            num_heads=cfg["n_heads"],
            dropout=cfg["drop_rate"],
            qkv_bias=cfg["qkv_bias"])
        self.ff = FeedForward(cfg)
        self.norm1 = LayerNorm(cfg["emb_dim"])
        self.norm2 = LayerNorm(cfg["emb_dim"])
        self.drop_shortcut = nn.Dropout(cfg["drop_rate"])

    def forward(self, x):
        # Shortcut connection for attention block
        shortcut = x
        x = self.norm1(x)
        x = self.att(x)  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        # Shortcut connection for feed forward block
        shortcut = x
        x = self.norm2(x)
        x = self.ff(x)
        # 2*4*768
        x = self.drop_shortcut(x)
        x = x + shortcut  # Add the original input back

        return x
        # 2*4*768

# %% [markdown]
# ### STEP 7: ENTIRE GPT MODEL ARCHITECTURE IMPLEMENTATION

# %%
class GPTModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
        self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
        self.drop_emb = nn.Dropout(cfg["drop_rate"])

        self.trf_blocks = nn.Sequential(
            *[TransformerBlock(cfg) for _ in range(cfg["n_layers"])])

        self.final_norm = LayerNorm(cfg["emb_dim"])
        self.out_head = nn.Linear(
            cfg["emb_dim"], cfg["vocab_size"], bias=False
        )

    def forward(self, in_idx):
        batch_size, seq_len = in_idx.shape
        tok_embeds = self.tok_emb(in_idx)
        pos_embeds = self.pos_emb(torch.arange(seq_len, device=in_idx.device))
        x = tok_embeds + pos_embeds  # Shape [batch_size, num_tokens, emb_size]
        x = self.drop_emb(x)
        x = self.trf_blocks(x)
        x = self.final_norm(x)
        logits = self.out_head(x)
        return logits

# %% [markdown]
# ### STEP 8: GENERATING TEXT FROM OUTPUT TOKENS

# %%
def generate_text_simple(model, idx, max_new_tokens, context_size):

    for _ in range(max_new_tokens):

        # Crop current context if it exceeds the supported context size
        # E.g., if LLM supports only 5 tokens, and the context size is 10
        # then only the last 5 tokens are used as context
        idx_cond = idx[:, -context_size:]

        # Get the predictions
        with torch.no_grad():
            logits = model(idx_cond) ### batch, n_tokens, vocab_size

        # Focus only on the last time step
        # (batch, n_tokens, vocab_size) becomes (batch, vocab_size)
        logits = logits[:, -1, :]

        # Apply softmax to get probabilities
        probas = torch.softmax(logits, dim=-1)  # (batch, vocab_size)

        # Get the idx of the vocab entry with the highest probability value
        idx_next = torch.argmax(probas, dim=-1, keepdim=True)  # (batch, 1)

        # Append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch, n_tokens+1)

    return idx

# %%
import tiktoken

def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text, allowed_special={'<|endoftext|>'})
    encoded_tensor = torch.tensor(encoded).unsqueeze(0)  # add batch dimension
    return encoded_tensor

def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0)  # remove batch dimension
    return tokenizer.decode(flat.tolist())

# %% [markdown]
# ### STEP 9: CREATING TRAINING, TESTING AND VALIDATION DATA

# %%
# Train/validation ratio
train_ratio = 0.90
split_idx = int(train_ratio * len(raw_text))
train_data = raw_text[:split_idx]
val_data = raw_text[split_idx:]


torch.manual_seed(123)

train_loader = create_dataloader_v1(
    train_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=True,
    shuffle=True,
    num_workers=0
)

val_loader = create_dataloader_v1(
    val_data,
    batch_size=2,
    max_length=GPT_CONFIG_124M["context_length"],
    stride=GPT_CONFIG_124M["context_length"],
    drop_last=False,
    shuffle=False,
    num_workers=0
)

# %% [markdown]
# ### STEP 10: DEFINING THE CROSS ENTROPY LOSS FUNCTION

# %%
def calc_loss_batch(input_batch, target_batch, model, device):
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    logits = model(input_batch)
    loss = torch.nn.functional.cross_entropy(logits.flatten(0, 1), target_batch.flatten())
    return loss


def calc_loss_loader(data_loader, model, device, num_batches=None):
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        # Reduce the number of batches to match the total number of batches in the data loader
        # if num_batches exceeds the number of batches in the data loader
        num_batches = min(num_batches, len(data_loader))
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            total_loss += loss.item()
        else:
            break
    return total_loss / num_batches

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model.to(device) # no assignment model = model.to(device) necessary for nn.Module classes


torch.manual_seed(123) # For reproducibility due to the shuffling in the data loader

with torch.no_grad(): # Disable gradient tracking for efficiency because we are not training, yet
    train_loss = calc_loss_loader(train_loader, model, device)
    val_loss = calc_loss_loader(val_loader, model, device)

print("Training loss:", train_loss)
print("Validation loss:", val_loss)
# Out:
# Training loss: 10.984648468380882
# Validation loss: 10.989548711634393

# %%
print(device)
# Out:
# cuda

# %% [markdown]
# ### STEP 11: TRAINING LOOP FOR THE LLM

# %%
def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode

        for input_batch, target_batch in train_loader:
            optimizer.zero_grad() # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward() # Calculate loss gradients
            optimizer.step() # Update model weights using loss gradients
            tokens_seen += input_batch.numel() # Returns the total number of elements (or tokens) in the input_batch.
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # Print a sample text after each epoch
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )

    return train_losses, val_losses, track_tokens_seen

# %%
def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss

# %%
def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=50, context_size=context_size
        )
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))  # Compact print format
    model.train()

# %%
import time
start_time = time.time()

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1) #A

num_epochs =5
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=1,
    start_context="There are four collections or Sa@mhitâs", tokenizer=tokenizer
)

end_time = time.time()
execution_time_minutes = (end_time - start_time) / 60
print(f"Training completed in {execution_time_minutes:.2f} minutes.")
# Out:
# Ep 1 (Step 000000): Train loss 9.868, Val loss 9.661
# Ep 1 (Step 000005): Train loss 8.568, Val loss 8.296
# Ep 1 (Step 000010): Train loss 7.344, Val loss 7.399
# Ep 1 (Step 000015): Train loss 7.067, Val loss 7.152
# Ep 1 (Step 000020): Train loss 7.268, Val loss 7.184
# Ep 1 (Step 000025): Train loss 7.209, Val loss 7.189
# Ep 1 (Step 000030): Train loss 6.556, Val loss 7.174
# Ep 1 (Step 000035): Train loss 6.758, Val loss 7.013
# Ep 1 (Step 000040): Train loss 6.810, Val loss 6.953
# Ep 1 (Step 000045): Train loss 6.716, Val loss 6.959
# Ep 1 (Step 000050): Train loss 6.989, Val loss 6.851
# Ep 1 (Step 000055): Train loss 6.883, Val loss 6.797
# Ep 1 (Step 000060): Train loss 6.448, Val loss 6.689
# Ep 1 (Step 000065): Train loss 6.549, Val loss 6.624
# Ep 1 (Step 000070): Train loss 6.275, Val loss 6.594
# Ep 1 (Step 000075): Train loss 6.084, Val loss 6.437
# Ep 1 (Step 000080): Train loss 6.013, Val loss 6.450
# Ep 1 (Step 000085): Train loss 6.206, Val loss 6.309
# Ep 1 (Step 000090): Train loss 6.229, Val loss 6.339
# Ep 1 (Step 000095): Train loss 6.146, Val loss 6.276
# Ep 1 (Step 000100): Train loss 6.242, Val loss 6.201
# Ep 1 (Step 000105): Train loss 6.252, Val loss 6.247
# Ep 1 (Step 000110): Train loss 6.012, Val loss 6.186
# Ep 1 (Step 000115): Train loss 6.687, Val loss 6.110
# Ep 1 (Step 000120): Train loss 5.336, Val loss 6.096
# Ep 1 (Step 000125): Train loss 6.053, Val loss 6.082
# Ep 1 (Step 000130): Train loss 5.337, Val loss 5.997
# Ep 1 (Step 000135): Train loss 5.960, Val loss 5.964
# Ep 1 (Step 000140): Train loss 6.584, Val loss 5.893
# Ep 1 (Step 000145): Train loss 5.840, Val loss 5.865
# Ep 1 (Step 000150): Train loss 6.216, Val loss 5.832
# Ep 1 (Step 000155): Train loss 5.787, Val loss 5.812
# Ep 1 (Step 000160): Train loss 6.056, Val loss 5.722
# Ep 1 (Step 000165): Train loss 5.428, Val loss 5.732
# Ep 1 (Step 000170): Train loss 5.798, Val loss 5.773
# Ep 1 (Step 000175): Train loss 5.969, Val loss 5.756
# Ep 1 (Step 000180): Train loss 5.746, Val loss 5.770
# Ep 1 (Step 000185): Train loss 5.483, Val loss 5.732
# Ep 1 (Step 000190): Train loss 6.219, Val loss 5.714
# Ep 1 (Step 000195): Train loss 5.725, Val loss 5.758
# Ep 1 (Step 000200): Train loss 5.709, Val loss 5.776
# Ep 1 (Step 000205): Train loss 5.885, Val loss 5.807
# Ep 1 (Step 000210): Train loss 5.641, Val loss 5.780
# Ep 1 (Step 000215): Train loss 5.381, Val loss 5.746
# Ep 1 (Step 000220): Train loss 5.917, Val loss 5.734
# Ep 1 (Step 000225): Train loss 5.335, Val loss 5.700
# Ep 1 (Step 000230): Train loss 5.501, Val loss 5.704
# Ep 1 (Step 000235): Train loss 5.334, Val loss 5.653
# Ep 1 (Step 000240): Train loss 5.885, Val loss 5.623
# Ep 1 (Step 000245): Train loss 5.062, Val loss 5.604
# Ep 1 (Step 000250): Train loss 5.376, Val loss 5.641
# Ep 1 (Step 000255): Train loss 5.750, Val loss 5.618
# Ep 1 (Step 000260): Train loss 5.795, Val loss 5.544
# Ep 1 (Step 000265): Train loss 5.392, Val loss 5.530
# Ep 1 (Step 000270): Train loss 4.833, Val loss 5.576
# Ep 1 (Step 000275): Train loss 5.238, Val loss 5.572
# Ep 1 (Step 000280): Train loss 5.120, Val loss 5.551
# Ep 1 (Step 000285): Train loss 5.788, Val loss 5.585
# Ep 1 (Step 000290): Train loss 5.200, Val loss 5.547
# Ep 1 (Step 000295): Train loss 5.230, Val loss 5.571
# Ep 1 (Step 000300): Train loss 5.030, Val loss 5.548
# Ep 1 (Step 000305): Train loss 5.504, Val loss 5.582
# Ep 1 (Step 000310): Train loss 5.435, Val loss 5.539
# Ep 1 (Step 000315): Train loss 5.786, Val loss 5.640
# Ep 1 (Step 000320): Train loss 4.973, Val loss 5.560
# Ep 1 (Step 000325): Train loss 5.477, Val loss 5.497
# Ep 1 (Step 000330): Train loss 4.868, Val loss 5.433
# Ep 1 (Step 000335): Train loss 5.223, Val loss 5.391
# Ep 1 (Step 000340): Train loss 5.011, Val loss 5.446
# Ep 1 (Step 000585): Train loss 4.926, Val loss 5.270
# Ep 1 (Step 000590): Train loss 5.380, Val loss 5.218
# Ep 1 (Step 000595): Train loss 4.484, Val loss 5.212
# Ep 1 (Step 000600): Train loss 4.910, Val loss 5.234
# Ep 1 (Step 000605): Train loss 4.736, Val loss 5.230
# Ep 1 (Step 000610): Train loss 4.630, Val loss 5.254
# Ep 1 (Step 000615): Train loss 4.811, Val loss 5.182
# Ep 1 (Step 000620): Train loss 4.711, Val loss 5.209
# Ep 1 (Step 000625): Train loss 4.941, Val loss 5.168
# There are four collections or Sa@mhitâs@s@s@s@s@s@mkhya,   the the the  the the the  the _S'a@s@s@s@s@s@s@
# Ep 2 (Step 000630): Train loss 4.494, Val loss 5.092
# Ep 2 (Step 000635): Train loss 4.438, Val loss 5.106
# Ep 2 (Step 000640): Train loss 4.617, Val loss 5.096
# Ep 2 (Step 000645): Train loss 5.110, Val loss 5.067
# Ep 2 (Step 000650): Train loss 4.939, Val loss 5.109
# Ep 2 (Step 000655): Train loss 6.185, Val loss 5.050
# Ep 2 (Step 000660): Train loss 4.926, Val loss 5.102
# Ep 2 (Step 000665): Train loss 4.333, Val loss 5.087
# Ep 2 (Step 000670): Train loss 4.798, Val loss 5.133
# Ep 2 (Step 000675): Train loss 4.668, Val loss 5.143
# Ep 2 (Step 000680): Train loss 4.104, Val loss 5.164
# Ep 2 (Step 000685): Train loss 4.362, Val loss 5.164
# Ep 2 (Step 000690): Train loss 4.642, Val loss 5.196
# Ep 2 (Step 000695): Train loss 5.111, Val loss 5.182
# Ep 2 (Step 000700): Train loss 4.381, Val loss 5.128
# Ep 2 (Step 000705): Train loss 4.226, Val loss 5.156
# Ep 2 (Step 000710): Train loss 4.511, Val loss 5.118
# Ep 2 (Step 000715): Train loss 5.511, Val loss 5.103
# Ep 2 (Step 000720): Train loss 4.463, Val loss 5.174
# Ep 2 (Step 000725): Train loss 4.588, Val loss 5.172
# Ep 2 (Step 000730): Train loss 5.009, Val loss 5.161
# Ep 2 (Step 000735): Train loss 5.021, Val loss 5.123
# Ep 2 (Step 000740): Train loss 4.797, Val loss 5.170
# Ep 2 (Step 000745): Train loss 4.680, Val loss 5.137
# Ep 2 (Step 000750): Train loss 4.812, Val loss 5.122
# Ep 2 (Step 000755): Train loss 5.122, Val loss 5.128
# Ep 2 (Step 000760): Train loss 5.301, Val loss 5.085
# Ep 2 (Step 000765): Train loss 4.138, Val loss 5.037
# Ep 2 (Step 000770): Train loss 4.170, Val loss 5.102
# Ep 2 (Step 000775): Train loss 4.315, Val loss 5.125
# Ep 2 (Step 000780): Train loss 4.301, Val loss 5.180
# Ep 2 (Step 000785): Train loss 4.837, Val loss 5.206
# Ep 2 (Step 000790): Train loss 4.552, Val loss 5.180
# Ep 2 (Step 000795): Train loss 4.978, Val loss 5.231
# Ep 2 (Step 000800): Train loss 5.233, Val loss 5.176
# Ep 2 (Step 000805): Train loss 4.693, Val loss 5.120
# Ep 2 (Step 000810): Train loss 4.600, Val loss 5.109
# Ep 3 (Step 001290): Train loss 4.255, Val loss 4.907
# Ep 3 (Step 001295): Train loss 4.854, Val loss 4.963
# Ep 3 (Step 001300): Train loss 3.452, Val loss 4.959
# Ep 3 (Step 001305): Train loss 3.966, Val loss 4.923
# Ep 3 (Step 001310): Train loss 4.065, Val loss 4.972
# Ep 3 (Step 001315): Train loss 4.462, Val loss 5.010
# Ep 3 (Step 001320): Train loss 4.366, Val loss 4.951
# Ep 3 (Step 001325): Train loss 3.722, Val loss 4.961
# Ep 3 (Step 001330): Train loss 3.800, Val loss 4.913
# Ep 3 (Step 001335): Train loss 3.886, Val loss 4.943
# Ep 3 (Step 001340): Train loss 4.098, Val loss 4.941
# Ep 3 (Step 001345): Train loss 4.593, Val loss 4.920
# Ep 3 (Step 001350): Train loss 4.321, Val loss 4.943
# Ep 3 (Step 001355): Train loss 3.879, Val loss 4.899
# Ep 3 (Step 001360): Train loss 4.575, Val loss 4.899
# Ep 3 (Step 001365): Train loss 3.765, Val loss 4.887
# Ep 3 (Step 001370): Train loss 4.409, Val loss 4.964
# Ep 3 (Step 001375): Train loss 3.771, Val loss 4.943
# Ep 3 (Step 001380): Train loss 4.288, Val loss 4.981
# Ep 3 (Step 001385): Train loss 4.845, Val loss 5.022
# Ep 3 (Step 001390): Train loss 4.126, Val loss 5.006
# Ep 3 (Step 001395): Train loss 4.166, Val loss 4.963
# Ep 3 (Step 001400): Train loss 3.922, Val loss 4.945
# Ep 3 (Step 001405): Train loss 3.571, Val loss 4.953
# Ep 3 (Step 001410): Train loss 5.009, Val loss 4.947
# Ep 3 (Step 001415): Train loss 4.172, Val loss 4.967
# Ep 3 (Step 001420): Train loss 4.495, Val loss 4.949
# Ep 3 (Step 001425): Train loss 4.325, Val loss 4.917
# Ep 3 (Step 001430): Train loss 3.815, Val loss 4.924
# Ep 3 (Step 001435): Train loss 3.774, Val loss 4.869
# Ep 3 (Step 001440): Train loss 4.009, Val loss 4.884
# Ep 3 (Step 001445): Train loss 3.672, Val loss 4.895
# Ep 3 (Step 001450): Train loss 5.178, Val loss 4.873
# Ep 3 (Step 001455): Train loss 4.296, Val loss 4.917
# Ep 3 (Step 001460): Train loss 3.812, Val loss 4.965
# Ep 3 (Step 001465): Train loss 4.412, Val loss 4.964
# Ep 3 (Step 001470): Train loss 4.346, Val loss 4.940
# Ep 3 (Step 001475): Train loss 4.060, Val loss 4.912
# Ep 3 (Step 001480): Train loss 4.239, Val loss 4.928
# Ep 3 (Step 001485): Train loss 4.242, Val loss 4.909
# Ep 3 (Step 001490): Train loss 4.204, Val loss 4.900
# Ep 3 (Step 001495): Train loss 4.152, Val loss 4.899
# Ep 3 (Step 001500): Train loss 4.424, Val loss 4.928
# Ep 3 (Step 001505): Train loss 3.861, Val loss 4.933
# Ep 3 (Step 001510): Train loss 4.317, Val loss 4.965
# Ep 3 (Step 001515): Train loss 4.266, Val loss 4.974
# Ep 3 (Step 001520): Train loss 4.072, Val loss 4.999
# Ep 3 (Step 001525): Train loss 4.503, Val loss 4.973
# Ep 3 (Step 001530): Train loss 3.860, Val loss 4.958
# Ep 3 (Step 001535): Train loss 4.449, Val loss 4.938
# Ep 3 (Step 001540): Train loss 4.083, Val loss 4.961
# Ep 3 (Step 001545): Train loss 3.842, Val loss 4.926
# Ep 3 (Step 001550): Train loss 3.842, Val loss 4.922
# Ep 3 (Step 001555): Train loss 4.007, Val loss 4.961
# Ep 3 (Step 001560): Train loss 3.306, Val loss 4.931
# Ep 3 (Step 001565): Train loss 4.054, Val loss 4.898
# Ep 3 (Step 001570): Train loss 4.155, Val loss 4.882
# Ep 3 (Step 001575): Train loss 3.333, Val loss 4.910
# Ep 3 (Step 001580): Train loss 4.136, Val loss 4.868
# Ep 3 (Step 001585): Train loss 4.457, Val loss 4.898
# Ep 3 (Step 001590): Train loss 4.061, Val loss 4.893
# Ep 3 (Step 001595): Train loss 4.156, Val loss 4.911
# Ep 3 (Step 001600): Train loss 4.799, Val loss 4.852
# Ep 3 (Step 001605): Train loss 4.139, Val loss 4.895
# Ep 3 (Step 001610): Train loss 4.241, Val loss 4.888
# Ep 3 (Step 001615): Train loss 4.115, Val loss 4.910
# Ep 3 (Step 001620): Train loss 3.808, Val loss 4.947
# Ep 3 (Step 001625): Train loss 3.888, Val loss 4.906
# Ep 3 (Step 001630): Train loss 4.565, Val loss 4.898
# Ep 3 (Step 001635): Train loss 3.735, Val loss 4.910
# Ep 3 (Step 001640): Train loss 4.033, Val loss 4.897
# Ep 3 (Step 001645): Train loss 3.404, Val loss 4.860
# Ep 3 (Step 001650): Train loss 4.633, Val loss 4.907
# Ep 3 (Step 001655): Train loss 3.887, Val loss 4.932
# Ep 3 (Step 001660): Train loss 4.260, Val loss 4.881
# Ep 3 (Step 001665): Train loss 3.983, Val loss 4.949
# Ep 3 (Step 001670): Train loss 3.962, Val loss 4.954
# Ep 3 (Step 001675): Train loss 3.998, Val loss 4.930
# Ep 3 (Step 001680): Train loss 3.322, Val loss 4.929
# Ep 3 (Step 001685): Train loss 4.199, Val loss 4.946
# Ep 3 (Step 001690): Train loss 3.973, Val loss 4.908
# Ep 3 (Step 001695): Train loss 4.151, Val loss 4.915
# Ep 3 (Step 001700): Train loss 3.484, Val loss 4.960
# Ep 3 (Step 001705): Train loss 4.168, Val loss 4.867
# Ep 3 (Step 001710): Train loss 3.637, Val loss 4.904
# Ep 3 (Step 001715): Train loss 3.598, Val loss 4.889
# Ep 3 (Step 001720): Train loss 4.616, Val loss 4.859
# Ep 3 (Step 001725): Train loss 4.138, Val loss 4.914
# Ep 3 (Step 001730): Train loss 4.228, Val loss 4.862
# Ep 3 (Step 001735): Train loss 3.943, Val loss 4.807
# Ep 3 (Step 001740): Train loss 3.934, Val loss 4.796
# Ep 3 (Step 001745): Train loss 3.960, Val loss 4.788
# Ep 3 (Step 001750): Train loss 4.226, Val loss 4.821
# Ep 3 (Step 001755): Train loss 4.508, Val loss 4.816
# Ep 3 (Step 001760): Train loss 3.837, Val loss 4.803
# Ep 3 (Step 001765): Train loss 3.769, Val loss 4.800
# Ep 3 (Step 001770): Train loss 3.891, Val loss 4.781
# Ep 3 (Step 001775): Train loss 3.947, Val loss 4.787
# Ep 3 (Step 001780): Train loss 3.765, Val loss 4.800
# Ep 3 (Step 001785): Train loss 4.158, Val loss 4.825
# Ep 3 (Step 001790): Train loss 3.744, Val loss 4.878
# Ep 3 (Step 001795): Train loss 4.082, Val loss 4.888
# Ep 3 (Step 001800): Train loss 3.923, Val loss 4.859
# Ep 3 (Step 001805): Train loss 3.630, Val loss 4.866
# Ep 3 (Step 001810): Train loss 3.954, Val loss 4.874
# Ep 3 (Step 001815): Train loss 4.210, Val loss 4.912
# Ep 3 (Step 001820): Train loss 3.895, Val loss 4.935
# Ep 3 (Step 001825): Train loss 3.749, Val loss 4.887
# Ep 3 (Step 001830): Train loss 3.452, Val loss 4.855
# Ep 3 (Step 001835): Train loss 4.102, Val loss 4.876
# Ep 3 (Step 001840): Train loss 3.749, Val loss 4.897
# Ep 3 (Step 001845): Train loss 4.036, Val loss 4.855
# Ep 3 (Step 001850): Train loss 4.165, Val loss 4.828
# Ep 3 (Step 001855): Train loss 4.217, Val loss 4.822
# Ep 3 (Step 001860): Train loss 3.417, Val loss 4.812
# Ep 3 (Step 001865): Train loss 4.433, Val loss 4.795
# Ep 3 (Step 001870): Train loss 4.033, Val loss 4.837
# Ep 3 (Step 001875): Train loss 4.040, Val loss 4.838
# Ep 3 (Step 001880): Train loss 4.243, Val loss 4.783
# Ep 3 (Step 001885): Train loss 3.779, Val loss 4.806
# There are four collections or Sa@mhitâsâ@msâ@msâ@msâ@msâ@msâ@msâ@msâ@msâ@msâ@msâ@msâ@msâ@msâ@msâ@msâ@msâ@
# Ep 4 (Step 001890): Train loss 3.860, Val loss 4.824
# Ep 4 (Step 001895): Train loss 4.124, Val loss 4.819
# Ep 4 (Step 001900): Train loss 4.058, Val loss 4.834
# Ep 4 (Step 001905): Train loss 4.045, Val loss 4.841
# Ep 4 (Step 001910): Train loss 4.023, Val loss 4.832
# Ep 4 (Step 001915): Train loss 3.729, Val loss 4.918
# Ep 4 (Step 001920): Train loss 4.152, Val loss 4.918
# Ep 4 (Step 001925): Train loss 3.970, Val loss 4.887
# Ep 4 (Step 001930): Train loss 4.023, Val loss 4.883
# Ep 4 (Step 001935): Train loss 4.148, Val loss 4.878
# Ep 4 (Step 001940): Train loss 3.607, Val loss 4.829
# Ep 4 (Step 001945): Train loss 3.881, Val loss 4.883
# Ep 4 (Step 001950): Train loss 2.901, Val loss 4.903
# Ep 4 (Step 001955): Train loss 3.857, Val loss 4.898
# Ep 4 (Step 001960): Train loss 3.931, Val loss 4.870
# Ep 4 (Step 001965): Train loss 3.699, Val loss 4.877
# Ep 4 (Step 001970): Train loss 4.114, Val loss 4.850
# Ep 4 (Step 001975): Train loss 3.662, Val loss 4.794
# Ep 4 (Step 001980): Train loss 3.373, Val loss 4.840
# Ep 4 (Step 001985): Train loss 3.824, Val loss 4.847
# Ep 4 (Step 001990): Train loss 3.942, Val loss 4.817
# Ep 4 (Step 001995): Train loss 3.979, Val loss 4.801
# Ep 4 (Step 002000): Train loss 3.716, Val loss 4.791
# Ep 4 (Step 002245): Train loss 3.820, Val loss 4.837
# Ep 4 (Step 002250): Train loss 3.040, Val loss 4.859
# Ep 4 (Step 002255): Train loss 3.904, Val loss 4.817
# Ep 4 (Step 002260): Train loss 3.809, Val loss 4.773
# Ep 4 (Step 002265): Train loss 3.298, Val loss 4.809
# Ep 4 (Step 002270): Train loss 3.149, Val loss 4.818
# Ep 4 (Step 002275): Train loss 3.598, Val loss 4.803
# Ep 4 (Step 002280): Train loss 3.946, Val loss 4.802
# Ep 4 (Step 002285): Train loss 3.597, Val loss 4.820
# Ep 4 (Step 002290): Train loss 3.806, Val loss 4.852
# Ep 4 (Step 002295): Train loss 4.128, Val loss 4.849
# Ep 4 (Step 002300): Train loss 3.968, Val loss 4.911
# Ep 4 (Step 002305): Train loss 3.891, Val loss 4.837
# Ep 4 (Step 002310): Train loss 3.206, Val loss 4.858
# Ep 4 (Step 002315): Train loss 4.066, Val loss 4.881
# Ep 4 (Step 002320): Train loss 3.461, Val loss 4.886
# Ep 4 (Step 002325): Train loss 4.173, Val loss 4.921
# Ep 4 (Step 002330): Train loss 3.679, Val loss 4.926
# Ep 4 (Step 002335): Train loss 4.051, Val loss 4.886
# Ep 4 (Step 002340): Train loss 3.852, Val loss 4.914
# Ep 4 (Step 002345): Train loss 3.573, Val loss 4.869
# Ep 4 (Step 002350): Train loss 3.825, Val loss 4.793
# Ep 4 (Step 002355): Train loss 3.815, Val loss 4.855
# Ep 4 (Step 002360): Train loss 3.631, Val loss 4.954
# Ep 4 (Step 002365): Train loss 3.336, Val loss 4.941
# Ep 4 (Step 002370): Train loss 3.862, Val loss 4.870
# Ep 4 (Step 002375): Train loss 3.603, Val loss 4.871
# Ep 4 (Step 002380): Train loss 3.343, Val loss 4.979
# Ep 4 (Step 002385): Train loss 3.486, Val loss 5.037
# Ep 4 (Step 002390): Train loss 3.694, Val loss 4.935
# Ep 4 (Step 002395): Train loss 3.642, Val loss 4.892
# Ep 4 (Step 002400): Train loss 3.300, Val loss 4.911
# Ep 4 (Step 002405): Train loss 3.354, Val loss 4.962
# Ep 4 (Step 002410): Train loss 3.478, Val loss 4.945
# Ep 4 (Step 002415): Train loss 3.517, Val loss 4.932
# Ep 4 (Step 002420): Train loss 3.658, Val loss 4.940
# Ep 4 (Step 002425): Train loss 3.922, Val loss 4.970
# Ep 4 (Step 002430): Train loss 3.369, Val loss 4.991
# Ep 4 (Step 002435): Train loss 3.269, Val loss 4.946
# Ep 4 (Step 002440): Train loss 3.454, Val loss 4.916
# Ep 4 (Step 002445): Train loss 3.434, Val loss 4.933
# Ep 4 (Step 002450): Train loss 3.676, Val loss 4.954
# Ep 4 (Step 002455): Train loss 3.077, Val loss 4.949
# Ep 4 (Step 002460): Train loss 3.805, Val loss 4.918
# Ep 4 (Step 002465): Train loss 3.399, Val loss 4.920
# Ep 4 (Step 002470): Train loss 3.940, Val loss 4.911
# Ep 4 (Step 002475): Train loss 3.248, Val loss 4.857
# Ep 4 (Step 002480): Train loss 3.388, Val loss 4.834
# Ep 4 (Step 002485): Train loss 3.219, Val loss 4.872
# Ep 4 (Step 002490): Train loss 3.582, Val loss 4.895
# Ep 4 (Step 002495): Train loss 3.317, Val loss 4.894
# Ep 4 (Step 002500): Train loss 3.766, Val loss 4.855
# Ep 4 (Step 002505): Train loss 3.420, Val loss 4.841
# Ep 4 (Step 002510): Train loss 3.141, Val loss 4.876
# Ep 4 (Step 002515): Train loss 3.523, Val loss 4.940
# There are four collections or Sa@mhitâsâ@nya@nya, and the and the and the _tâ_ (the _tâ_ (universe) and _tâ_ (universe) and _tathâ_ (unis'
# Ep 5 (Step 002520): Train loss 3.427, Val loss 4.875
# Ep 5 (Step 002525): Train loss 3.385, Val loss 4.849
# Ep 5 (Step 002530): Train loss 3.365, Val loss 4.939
# Ep 5 (Step 002535): Train loss 3.407, Val loss 4.945
# Ep 5 (Step 002540): Train loss 2.919, Val loss 4.956
# Ep 5 (Step 002545): Train loss 3.097, Val loss 4.987
# Ep 5 (Step 002550): Train loss 3.355, Val loss 4.976
# Ep 5 (Step 002555): Train loss 3.531, Val loss 4.956
# Ep 5 (Step 002560): Train loss 3.718, Val loss 4.959
# Ep 5 (Step 002565): Train loss 3.146, Val loss 4.952
# Ep 5 (Step 002570): Train loss 3.271, Val loss 4.914
# Ep 5 (Step 002575): Train loss 3.375, Val loss 4.939
# Ep 5 (Step 002580): Train loss 3.473, Val loss 4.949
# Ep 5 (Step 002585): Train loss 2.988, Val loss 4.935
# Ep 5 (Step 002590): Train loss 3.073, Val loss 4.941
# Ep 5 (Step 002595): Train loss 3.227, Val loss 4.944
# Ep 5 (Step 002600): Train loss 3.374, Val loss 4.996
# Ep 5 (Step 002605): Train loss 3.555, Val loss 4.994
# Ep 5 (Step 002610): Train loss 3.471, Val loss 4.980
# Ep 5 (Step 002615): Train loss 3.737, Val loss 4.966
# Ep 5 (Step 002620): Train loss 3.072, Val loss 5.014
# Ep 5 (Step 002625): Train loss 3.250, Val loss 4.995
# Ep 5 (Step 002630): Train loss 3.590, Val loss 4.989
# Ep 5 (Step 002635): Train loss 3.061, Val loss 5.010
# Ep 5 (Step 002640): Train loss 3.406, Val loss 5.002
# Ep 5 (Step 002645): Train loss 2.093, Val loss 4.999
# Ep 5 (Step 002650): Train loss 3.407, Val loss 5.040
# Ep 5 (Step 002655): Train loss 3.030, Val loss 5.027
# Ep 5 (Step 002660): Train loss 3.668, Val loss 4.973
# Ep 5 (Step 002665): Train loss 3.695, Val loss 4.964
# Ep 5 (Step 002670): Train loss 3.622, Val loss 5.002
# Ep 5 (Step 002675): Train loss 3.430, Val loss 5.040
# Ep 5 (Step 002680): Train loss 2.849, Val loss 4.995
# Ep 5 (Step 002685): Train loss 3.696, Val loss 4.939
# Ep 5 (Step 002690): Train loss 3.023, Val loss 4.958
# Ep 5 (Step 002695): Train loss 3.369, Val loss 5.018
# Ep 5 (Step 002700): Train loss 3.350, Val loss 4.967
# Ep 5 (Step 002705): Train loss 3.827, Val loss 4.932
# Ep 5 (Step 002710): Train loss 2.848, Val loss 5.005
# Ep 5 (Step 002715): Train loss 2.819, Val loss 5.055
# Ep 5 (Step 002720): Train loss 3.541, Val loss 5.065
# Ep 5 (Step 002725): Train loss 3.537, Val loss 5.086
# Ep 5 (Step 002730): Train loss 3.751, Val loss 5.114
# Ep 5 (Step 002735): Train loss 3.423, Val loss 5.079
# Ep 5 (Step 002740): Train loss 2.950, Val loss 5.094
# Ep 5 (Step 002745): Train loss 3.874, Val loss 5.007
# Ep 5 (Step 002750): Train loss 3.020, Val loss 4.968
# Ep 5 (Step 002755): Train loss 3.354, Val loss 5.007
# Ep 5 (Step 002760): Train loss 2.969, Val loss 5.030
# Ep 5 (Step 002765): Train loss 3.577, Val loss 4.990
# Ep 5 (Step 002770): Train loss 2.826, Val loss 4.951
# Ep 5 (Step 002775): Train loss 2.423, Val loss 5.004
# Ep 5 (Step 002780): Train loss 2.882, Val loss 4.949
# Ep 5 (Step 002785): Train loss 3.319, Val loss 4.907
# Ep 5 (Step 002790): Train loss 2.639, Val loss 4.943
# Ep 5 (Step 002795): Train loss 3.425, Val loss 4.919
# Ep 5 (Step 002800): Train loss 3.072, Val loss 4.904
# Ep 5 (Step 002805): Train loss 3.058, Val loss 4.894
# Ep 5 (Step 002810): Train loss 3.180, Val loss 4.941
# Ep 5 (Step 002815): Train loss 3.095, Val loss 4.962
# Ep 5 (Step 002820): Train loss 2.731, Val loss 4.977
# Ep 5 (Step 002825): Train loss 3.454, Val loss 5.033
# Ep 5 (Step 002830): Train loss 3.670, Val loss 5.040
# Ep 5 (Step 002835): Train loss 3.016, Val loss 5.046
# Ep 5 (Step 002840): Train loss 2.472, Val loss 5.044
# Ep 5 (Step 002845): Train loss 2.775, Val loss 5.008
# Ep 5 (Step 002850): Train loss 2.995, Val loss 4.962
# Ep 5 (Step 002855): Train loss 3.164, Val loss 4.965
# Ep 5 (Step 002860): Train loss 2.600, Val loss 4.950
# Ep 5 (Step 002865): Train loss 3.043, Val loss 4.954
# Ep 5 (Step 002870): Train loss 3.335, Val loss 4.936
# Ep 5 (Step 002875): Train loss 2.963, Val loss 4.933
# Ep 5 (Step 002880): Train loss 3.152, Val loss 4.892
# Ep 5 (Step 002885): Train loss 2.993, Val loss 4.918
# Ep 5 (Step 002890): Train loss 3.564, Val loss 5.012
# Ep 5 (Step 002895): Train loss 3.007, Val loss 4.939
# Ep 5 (Step 002900): Train loss 3.889, Val loss 4.875
# Ep 5 (Step 002905): Train loss 3.182, Val loss 4.880
# Ep 5 (Step 002910): Train loss 3.268, Val loss 4.884
# Ep 5 (Step 002915): Train loss 3.274, Val loss 4.890
# Ep 5 (Step 002920): Train loss 3.245, Val loss 4.977
# Ep 5 (Step 002925): Train loss 3.801, Val loss 5.017
# Ep 5 (Step 002930): Train loss 3.183, Val loss 4.955
# Ep 5 (Step 002935): Train loss 3.757, Val loss 4.938
# Ep 5 (Step 002940): Train loss 3.119, Val loss 4.889
# Ep 5 (Step 002945): Train loss 2.893, Val loss 4.850
# Ep 5 (Step 002950): Train loss 3.603, Val loss 4.899
# Ep 5 (Step 002955): Train loss 2.843, Val loss 4.948
# Ep 5 (Step 002960): Train loss 3.099, Val loss 4.892
# Ep 5 (Step 002965): Train loss 2.737, Val loss 4.908
# Ep 5 (Step 002970): Train loss 3.811, Val loss 4.982
# Ep 5 (Step 002975): Train loss 3.016, Val loss 4.985
# Ep 5 (Step 002980): Train loss 4.330, Val loss 4.930
# Ep 5 (Step 002985): Train loss 3.916, Val loss 4.947
# Ep 5 (Step 002990): Train loss 2.870, Val loss 5.020
# Ep 5 (Step 002995): Train loss 3.392, Val loss 4.986
# Ep 5 (Step 003000): Train loss 3.272, Val loss 4.977
# Ep 5 (Step 003005): Train loss 3.541, Val loss 4.973
# Ep 5 (Step 003010): Train loss 2.992, Val loss 4.902
# Ep 5 (Step 003015): Train loss 3.457, Val loss 4.936
# Ep 5 (Step 003020): Train loss 3.279, Val loss 4.941
# Ep 5 (Step 003025): Train loss 2.702, Val loss 4.948
# Ep 5 (Step 003030): Train loss 2.872, Val loss 4.978
# Ep 5 (Step 003035): Train loss 2.692, Val loss 4.969
# Ep 5 (Step 003040): Train loss 3.497, Val loss 4.963
# Ep 5 (Step 003045): Train loss 3.072, Val loss 4.949
# Ep 5 (Step 003050): Train loss 3.033, Val loss 4.926
# Ep 5 (Step 003055): Train loss 2.830, Val loss 4.923
# Ep 5 (Step 003060): Train loss 2.995, Val loss 4.918
# Ep 5 (Step 003065): Train loss 3.376, Val loss 4.913
# Ep 5 (Step 003070): Train loss 2.934, Val loss 4.901
# Ep 5 (Step 003075): Train loss 2.841, Val loss 4.950
# Ep 5 (Step 003080): Train loss 2.959, Val loss 4.912
# Ep 5 (Step 003085): Train loss 2.852, Val loss 4.915
# Ep 5 (Step 003090): Train loss 3.182, Val loss 4.860
# Ep 5 (Step 003095): Train loss 2.928, Val loss 4.864
# Ep 5 (Step 003100): Train loss 2.902, Val loss 4.887
# Ep 5 (Step 003105): Train loss 2.837, Val loss 4.915
# Ep 5 (Step 003110): Train loss 2.821, Val loss 4.889
# Ep 5 (Step 003115): Train loss 2.895, Val loss 4.848
# Ep 5 (Step 003120): Train loss 3.060, Val loss 4.907
# Ep 5 (Step 003125): Train loss 2.697, Val loss 4.927
# Ep 5 (Step 003130): Train loss 3.252, Val loss 4.880
# Ep 5 (Step 003135): Train loss 2.985, Val loss 4.907
# Ep 5 (Step 003140): Train loss 2.649, Val loss 4.928
# Ep 5 (Step 003145): Train loss 2.971, Val loss 4.895
# There are four collections or Sa@mhitâs'vagho@nkhya, and vijjâ, and the and the vâ, vijjâ, and the and the tanmâ, and the and the tamas, and the tamas,
# Training completed in 11.57 minutes.

# %% [markdown]
# As we can see, based on the results printed during the training, the training loss improve drastically, starting with a value of 9.868 and converging to 2.971.
#
#
# Similar to the training set loss, we can see that the validation loss starts high (9.661)
# and decreases during the training to 4.895.

# %%
# Model summary after training
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params:,}")

print("Token embedding layer shape:", model.tok_emb.weight.shape)
print("Output layer shape:", model.out_head.weight.shape)

total_size_bytes = total_params * 4
total_size_mb = total_size_bytes / (1024 * 1024)
print(f"Total size of the model: {total_size_mb:.2f} MB")
# Out:
# Total number of parameters: 162,419,712
# Token embedding layer shape: torch.Size([50257, 768])
# Output layer shape: torch.Size([50257, 768])
# Total size of the model: 619.58 MB

# %% [markdown]
# ### STEP 12: PLOTTING THE LOSSES

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator


def plot_losses(epochs_seen, tokens_seen, train_losses, val_losses):
    fig, ax1 = plt.subplots(figsize=(5, 3))

    # Plot training and validation loss against epochs
    ax1.plot(epochs_seen, train_losses, label="Training loss")
    ax1.plot(epochs_seen, val_losses, linestyle="-.", label="Validation loss")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")
    ax1.legend(loc="upper right")
    ax1.xaxis.set_major_locator(MaxNLocator(integer=True))  # only show integer labels on x-axis

    # Create a second x-axis for tokens seen
    ax2 = ax1.twiny()  # Create a second x-axis that shares the same y-axis
    ax2.plot(tokens_seen, train_losses, alpha=0)  # Invisible plot for aligning ticks
    ax2.set_xlabel("Tokens seen")

    fig.tight_layout()  # Adjust layout to make room
    plt.savefig("loss-plot.pdf")
    plt.show()

epochs_tensor = torch.linspace(0, num_epochs, len(train_losses))
plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses)

# %% [markdown]
# ### STEP 13: IMPLEMENTING TEMPERATURE SCALING AND TOP-K SAMPLING

# %%
def generate(model, idx, max_new_tokens, context_size, temperature=0.0, top_k=None, eos_id=None):

    # For-loop is the same as before: Get logits, and only focus on last time step
    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)
        logits = logits[:, -1, :]

        # New: Filter logits with top_k sampling
        if top_k is not None:
            # Keep only top_k values
            top_logits, _ = torch.topk(logits, top_k)
            min_val = top_logits[:, -1]
            logits = torch.where(logits < min_val, torch.tensor(float("-inf")).to(logits.device), logits)

        # New: Apply temperature scaling
        if temperature > 0.0:
            logits = logits / temperature

            # Apply softmax to get probabilities
            probs = torch.softmax(logits, dim=-1)  # (batch_size, context_len)

            # Sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1)  # (batch_size, 1)

        # Otherwise same as before: get idx of the vocab entry with the highest logits value
        else:
            idx_next = torch.argmax(logits, dim=-1, keepdim=True)  # (batch_size, 1)

        if idx_next == eos_id:  # Stop generating early if end-of-sequence token is encountered and eos_id is specified
            break

        # Same as before: append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch_size, num_tokens+1)

    return idx

# %%
import torch

# Set random seed for reproducibility
torch.manual_seed(123)

# Define the device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move model to the device
model = model.to(device)

# Prepare token_ids
token_ids = text_to_token_ids("Every effort moves you", tokenizer)
token_ids = token_ids.to(device)  # Move token_ids to the correct device

# Generate text with specific parameters
token_ids = generate(
    model=model,
    idx=token_ids,  # Ensure token_ids are on the correct device
    max_new_tokens=15,
    context_size=GPT_CONFIG_124M["context_length"],
    top_k=25,
    temperature=1.4
)

# Convert token_ids back to text and print
print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# Output text:
#  Every effort moves you could only could come into any sacrifice for all them. It is said
